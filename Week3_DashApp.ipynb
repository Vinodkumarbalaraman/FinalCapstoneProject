# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in c:\users\suvi\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\suvi\anaconda3\lib\site-packages (from dash) (4.11.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\suvi\anaconda3\lib\site-packages (from dash) (1.15.0)
# Requirement already satisfied: flask-compress in c:\users\suvi\anaconda3\lib\site-packages (from dash) (1.13)
# Requirement already satisfied: future in c:\users\suvi\anaconda3\lib\site-packages (from dash) (0.18.3)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\suvi\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\suvi\anaconda3\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\suvi\anaconda3\lib\site-packages (from dash) (1.9.0)
# Requirement already satisfied: plotly in c:\users\suvi\anaconda3\lib\site-packages (from dash) (5.14.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: brotli in c:\users\suvi\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\suvi\anaconda3\lib\site-packages (from plotly->dash) (8.0.1)
# Requirement already satisfied: packaging in c:\users\suvi\anaconda3\lib\site-packages (from plotly->dash) (22.0)
# Requirement already satisfied: colorama in c:\users\suvi\anaconda3\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\suvi\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.1.1)
# Requirement already satisfied: dash==1.19.0 in c:\users\suvi\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (1.13)
# Requirement already satisfied: plotly in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (5.14.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (2.2.2)
# Requirement already satisfied: future in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.3)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\suvi\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: click>=8.0 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.4)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\suvi\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: brotli in c:\users\suvi\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: packaging in c:\users\suvi\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\suvi\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: colorama in c:\users\suvi\anaconda3\lib\site-packages (from click>=8.0->Flask>=1.0.4->dash==1.19.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\suvi\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==1.19.0) (2.1.1)
# Requirement already satisfied: jupyter_dash in c:\users\suvi\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (1.5.6)
# Requirement already satisfied: requests in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (2.28.1)
# Requirement already satisfied: dash in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ansi2html in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: flask in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (2.2.2)
# Requirement already satisfied: ipykernel in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (6.19.2)
# Requirement already satisfied: retrying in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: ipython in c:\users\suvi\anaconda3\lib\site-packages (from jupyter_dash) (8.10.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\suvi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: flask-compress in c:\users\suvi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.13)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\suvi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\suvi\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\suvi\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: plotly in c:\users\suvi\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.14.0)
# Requirement already satisfied: future in c:\users\suvi\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\suvi\anaconda3\lib\site-packages (from flask->jupyter_dash) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\suvi\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\suvi\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\suvi\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: psutil in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.9.0)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (23.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (7.3.4)
# Requirement already satisfied: packaging in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (22.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\suvi\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.36)
# Requirement already satisfied: pickleshare in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: decorator in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: backcall in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: colorama in c:\users\suvi\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\suvi\anaconda3\lib\site-packages (from requests->jupyter_dash) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\suvi\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\suvi\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\suvi\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.14)
# Requirement already satisfied: six>=1.7.0 in c:\users\suvi\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\suvi\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\suvi\anaconda3\lib\site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suvi\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\suvi\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\suvi\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (5.2.0)
# Requirement already satisfied: wcwidth in c:\users\suvi\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\suvi\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\suvi\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: pure-eval in c:\users\suvi\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\suvi\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: executing in c:\users\suvi\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\suvi\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\suvi\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.5.2)
# Requirement already satisfied: plotly in c:\users\suvi\anaconda3\lib\site-packages (5.14.0)
# Requirement already satisfied: packaging in c:\users\suvi\anaconda3\lib\site-packages (from plotly) (22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\suvi\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 import dash
#       3 import dash_html_components as html
#       4 import dash_core_components as dcc
#
# File ~\anaconda3\lib\site-packages\dash\__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (C:\Users\Suvi\anaconda3\lib\site-packages\werkzeug\debug\tbtools.py)

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# %%
# skeleton Dash app to be completed in this lab, downloaded from:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py
# redundant lines commented out

# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
# app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
